# %% [markdown]
# ### Library Pandas

# %%
import pandas as pd

# %%
bank_db = {
    'Name' : ['Alex Smith', 'Bulat Semenov'],
    'Age' : [0, 1],
    'Experience' : [4, 7],
    'Salary' : [75, 95],
    'Credit_score' : [4, 8],
    'Outcome' : [0, 1]
}

# %%
# Creating DataFrame
df = pd.DataFrame(bank_db)

# %%
df
# Out:
#             Name  Age  Experience  Salary  Credit_score  Outcome
# 0     Alex Smith    0           4      75             4        0
# 1  Bulat Semenov    1           7      95             8        1

# %%
# Calculate the average income of borrowers
df['Salary'].mean()
# Out:
# 85.0

# %% [markdown]
# ### Library Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Function `plot` use to build line graphs by connecting points with data provided as lists or arrays

# %%
plt.plot([70, 80, 100, 150, 300], [1, 4, 6, 9, 16])

plt.xlabel('Profit, $')
plt.ylabel('Happiness')
plt.title('Happiness and profit')

plt.show()

# %% [markdown]
# Feature of the `plt.show()` is that without using it, you can build two or more graphs on the same coorindate axis.

# %%
plt.plot([70, 80, 100, 150, 300], [1, 4, 6, 9, 16])
plt.plot([39, 50, 80, 100, 200, 300], [1, 4, 7, 9, 18, 22])

# %%
plt.plot([70, 80, 100, 150, 300], [1, 4, 6, 9, 16])
plt.show()
plt.plot([39, 50, 80, 100, 200, 300], [1, 4, 7, 9, 18, 22])
plt.show()

# %% [markdown]
# We can use some params to set style of graphs

# %%
X = [50, 60, 70, 90]
y = [1, 5, 6, 11]

plt.plot(X, y, color='cyan', linestyle='--', marker='D')

plt.show()
